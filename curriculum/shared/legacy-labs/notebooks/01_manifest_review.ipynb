# %% [markdown]
# # Review an MCP manifest
# Tool metadata is untrusted input. We inventory names and schemas before approval.
#
# ## Reflection
# Why should an arbitrary URL field require an explicit egress policy?

# %%
import runpy
runpy.run_path('../beginner/01_manifest_inventory.py',run_name='__main__')
