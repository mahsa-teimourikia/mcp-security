# %% [markdown]
# # Provenance release gate
# Require an approved digest, signature, and clean vulnerability findings.
#
# ## Reflection
# Which control lets you roll back to a known-good server after a package compromise?

# %%
import runpy
runpy.run_path('../intermediate/01_provenance_gate.py',run_name='__main__')
