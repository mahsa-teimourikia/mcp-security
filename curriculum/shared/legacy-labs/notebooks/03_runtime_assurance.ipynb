# %% [markdown]
# # Runtime assurance
# Use telemetry signals to distinguish baseline behavior from an unknown digest, unsafe destination, repeated denials, or injected output instructions.
#
# ## Reflection
# Why should anomaly detection trigger a risk gate rather than grant permission?
#
# ## Reflection

# %%
import runpy
runpy.run_path('../intermediate/03_runtime_policy.py',run_name='__main__')
